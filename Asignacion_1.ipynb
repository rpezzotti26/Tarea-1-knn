# %%
# !git config --global user.email "robertopezzotti143@gmail.com"
# !git config --global user.name "rpezzotti26"


USUARIO = "rpezzotti26"
TOKEN = "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"
REPO = "Asignacion-1-IA"


repo_url = f"https://{TOKEN}@github.com/{USUARIO}/{REPO}.git"


# !git clone {repo_url}


# %cd {REPO}


# !cp /content/Untitled1.ipynb .
# !cp /content/cleaned_dataset.csv .

# Mandamos los cambios a GitHub
# !git add .
# !git commit -m "Subiendo mi tarea de KNN - Accuracy 81%"
# !git push origin main
# Out:
# Cloning into 'Asignacion-1-IA'...
# ...
# /content/Asignacion-1-IA
# cp: cannot stat '/content/Untitled1.ipynb': No such file or directory
# [main (root-commit) d24c6a1] Subiendo mi tarea de KNN - Accuracy 81%
#  1 file changed, 393 insertions(+)
#  create mode 100644 cleaned_dataset.csv
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 5.01 KiB | 1.25 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/rpezzotti26/Asignacion-1-IA.git
#  * [new branch]      main -> main

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# PASO 1: Cargar el archivo con el nombre que Python SÍ encontró
df = pd.read_csv('/content/cleaned_dataset.csv')
print("¡Archivo detectado y cargado correctamente!")

# PASO 2: Crear subconjuntos de 20 datos para entrenamiento y 20 para testeo
train_small = df.head(20)
test_small = df.iloc[20:40]

# PASO 3: Función de distancia euclidiana (según la fórmula de tu tarea)
def distancia_euclidiana(v1, v2):
    return np.sqrt(np.sum((np.array(v1) - np.array(v2))**2))

# Prueba manual que pide el Paso 3
v1 = [1, 106, 70, 28, 135, 34.2, 0.142, 22]
v2 = [2, 102, 86, 36, 120, 45.5, 0.127, 23]
dist = distancia_euclidiana(v1, v2)
print(f"\nDistancia Euclidiana entre v1 y v2: {dist:.4f}")

# PASO 5: Usar toda la data con separación 80% / 20%
X = df.drop('Outcome', axis=1) # Características (Pregnancies, Glucose, etc.)
y = df['Outcome']              # Resultado (0 o 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=42)

# Función para entrenar KNN y calcular el Accuracy (Pasos 6, 7 y 9)
def ejecutar_knn(X_entreno, X_val):
    knn = KNeighborsClassifier(n_neighbors=3, metric='euclidean') # k=3 y Euclideano
    knn.fit(X_entreno, y_train)
    predicciones = knn.predict(X_val)
    return accuracy_score(y_test, predicciones)

# PASO 6: Accuracy con datos crudos (sin escalar)
acc_crudo = ejecutar_knn(X_train, X_test)

# PASO 7: Accuracy con Normalización (Min-Max)
scaler_norm = MinMaxScaler()
X_train_norm = scaler_norm.fit_transform(X_train)
X_test_norm = scaler_norm.transform(X_test)
acc_norm = ejecutar_knn(X_train_norm, X_test_norm)

# PASO 9: Accuracy con Estandarización (Z-score)
scaler_std = StandardScaler()
X_train_std = scaler_std.fit_transform(X_train)
X_test_std = scaler_std.transform(X_test)
acc_std = ejecutar_knn(X_train_std, X_test_std)

# PASO 10/11: Tabla comparativa de resultados
print("\n--- TABLA COMPARATIVA DE ACCURACIES ---")
resultados = pd.DataFrame({
    'Metodología': ['KNN sin escalar (80/20)', 'KNN normalizado (80/20)', 'KNN estandarizado (80/20)'],
    'Accuracy (Precisión)': [acc_crudo, acc_norm, acc_std]
})
print(resultados)


# PASO 4: Clasificador KNN básico - Comparativa de 10 muestras
print("--- PASO 4: COMPARATIVA REAL VS PREDICHO (10 MUESTRAS) ---")

# Tomamos 10 muestras del conjunto de prueba
muestras_prueba = X_test.iloc[:10]
valores_reales = y_test.iloc[:10].values

# Usamos el modelo para predecir
predicciones_10 = KNeighborsClassifier(n_neighbors=3).fit(X_train, y_train).predict(muestras_prueba)

# Creamos la tabla que pide tu instrucción
tabla_paso4 = pd.DataFrame({
    'Muestra': range(1, 11),
    'Valor Real (Resultado)': valores_reales,
    'Valor Predicho': predicciones_10
})

print(tabla_paso4)

# --- 1. CONFIGURACIÓN ---
# !git config --global user.email "robertopezzotti143@gmail.com"
# !git config --global user.name "rpezzotti26"

USUARIO = "rpezzotti26"
TOKEN = "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"
REPO = "Tarea-1-knn"

# --- 2. LIMPIEZA TOTAL ---
# %cd /content/
# !rm -rf {REPO}
repo_url = f"https://{TOKEN}@github.com/{USUARIO}/{REPO}.git"
# !git clone {repo_url}

# --- 3. COPIAR ARCHIVOS (FORZADO) ---
# Copiamos el archivo que Colab detectó como 'Asignacion-1-IA'
# y le ponemos la extensión .ipynb para que GitHub lo reconozca como código
# !cp "/content/Asignacion-1-IA" "/content/{REPO}/Asignacion-1-IA.ipynb"
# !cp "/content/cleaned_dataset.csv" "/content/{REPO}/"

# --- 4. SUBIDA ---
# %cd {REPO}
# !git add .
# !git commit -m "Subida de código y datos corregida"
# !git push origin main
# Out:
# ¡Archivo detectado y cargado correctamente!
#
# Distancia Euclidiana entre v1 y v2: 26.2810
#
# --- TABLA COMPARATIVA DE ACCURACIES ---
#                  Metodología  Accuracy (Precisión)
# 0    KNN sin escalar (80/20)              0.810127
# 1    KNN normalizado (80/20)              0.734177
# 2  KNN estandarizado (80/20)              0.746835
# --- PASO 4: COMPARATIVA REAL VS PREDICHO (10 MUESTRAS) ---
#    Muestra  Valor Real (Resultado)  Valor Predicho
# 0        1                       1               0
# 1        2                       0               0
# 2        3                       0               0
# 3        4                       1               1
# 4        5                       1               0
# 5        6                       0               1
# 6        7                       0               0
# 7        8                       0               0
# 8        9                       1               0
# 9       10                       0               0
# ...
